# %%
import os
import json
import pandas as pd

# Define file path
file_path = "C:/Users/colte/lhl-mt/data/AK_Juneau_0.json"

# Load JSON file
with open(file_path, "r") as f:
    data = json.load(f)

# Extract the 'results' field inside 'data'
if "data" in data and "results" in data["data"]:
    df = pd.DataFrame(data["data"]["results"])
    print("Successfully extracted 'results'!")
    print("Shape:", df.shape)
else:
    print("No 'results' field found in JSON!")

# Display the first few rows
df.head()
# Out:
# Successfully extracted 'results'!
# Shape: (8, 23)
#                                        primary_photo      last_update_date  \
# 0  {'href': 'https://ap.rdcpix.com/07097d34c98a59...  2023-09-19T20:52:50Z
# 1                                               None                  None
# 2                                               None                  None
# 3                                               None                  None
# 4                                               None                  None
#
#                                               source  \
# 0  {'plan_id': None, 'agents': [{'office_name': '...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                                 tags  \
# 0  [carport, community_outdoor_space, cul_de_sac,...
# ...

# %%
from functions_variables import encode_tags
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 from functions_variables import encode_tags
#
# ModuleNotFoundError: No module named 'functions_variables'

# %%
import os
print(os.listdir())
# Out:
# ['.gitkeep', '.ipynb_checkpoints', 'AK_Juneau_0.json', 'AK_Juneau_1.json', 'AK_Juneau_2.json', 'AK_Juneau_3.json', 'AK_Juneau_4.json', 'AL_Montgomery_0.json', 'AL_Montgomery_1.json', 'AL_Montgomery_2.json', 'AL_Montgomery_3.json', 'AL_Montgomery_4.json', 'AR_LittleRock_0.json', 'AR_LittleRock_1.json', 'AR_LittleRock_2.json', 'AR_LittleRock_3.json', 'AR_LittleRock_4.json', 'AZ_Phoenix_0.json', 'AZ_Phoenix_1.json', 'AZ_Phoenix_2.json', 'AZ_Phoenix_3.json', 'AZ_Phoenix_4.json', 'CA_Sacramento_0.json', 'CA_Sacramento_1.json', 'CA_Sacramento_2.json', 'CA_Sacramento_3.json', 'CA_Sacramento_4.json', 'CO_Denver_0.json', 'CO_Denver_1.json', 'CO_Denver_2.json', 'CO_Denver_3.json', 'CO_Denver_4.json', 'CT_Hartford_0.json', 'CT_Hartford_1.json', 'CT_Hartford_2.json', 'CT_Hartford_3.json', 'CT_Hartford_4.json', 'DE_Dover_0.json', 'DE_Dover_1.json', 'DE_Dover_2.json', 'DE_Dover_3.json', 'DE_Dover_4.json', 'FL_Tallahassee_0.json', 'FL_Tallahassee_1.json', 'FL_Tallahassee_2.json', 'FL_Tallahassee_3.
# ...
